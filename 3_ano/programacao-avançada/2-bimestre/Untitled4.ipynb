# %% [markdown]
# # Fundamentos Panda

# %%
import pandas as pd
import numpy as np

# %%
datas = pd.date_range("20100101", periods = 10)
print(datas)
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-02', '2010-01-03', '2010-01-04',
#                '2010-01-05', '2010-01-06', '2010-01-07', '2010-01-08',
#                '2010-01-09', '2010-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
datas1 = pd.date_range("20100101", periods = 12, freq = "M")
print(datas1)
# Out:
# DatetimeIndex(['2010-01-31', '2010-02-28', '2010-03-31', '2010-04-30',
#                '2010-05-31', '2010-06-30', '2010-07-31', '2010-08-31',
#                '2010-09-30', '2010-10-31', '2010-11-30', '2010-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
datas2 = pd.date_range(start = "2015", end="2022")
print(datas2)
# Out:
# DatetimeIndex(['2015-01-01', '2015-01-02', '2015-01-03', '2015-01-04',
#                '2015-01-05', '2015-01-06', '2015-01-07', '2015-01-08',
#                '2015-01-09', '2015-01-10',
#                ...
#                '2021-12-23', '2021-12-24', '2021-12-25', '2021-12-26',
#                '2021-12-27', '2021-12-28', '2021-12-29', '2021-12-30',
#                '2021-12-31', '2022-01-01'],
#               dtype='datetime64[ns]', length=2558, freq='D')

# %%
df = pd.DataFrame(np.random.randn(10,4), index = datas, columns = list("ABCD"))

# %%
df.head(5)
# Out:
#                    A         B         C         D
# 2010-01-01  0.179247 -0.291639  2.366467  1.035198
# 2010-01-02 -1.406596  1.479197 -0.824970  0.188342
# 2010-01-03  2.085567  0.243272 -0.437745  1.059762
# 2010-01-04  1.148738 -0.118400  0.214420 -0.172060
# 2010-01-05  0.113355 -0.568552 -1.745380 -0.725726

# %%
np.random.randn(10,4)
# Out:
# array([[-0.35532706,  0.85871309,  0.14837208, -0.35366005],
#        [-0.17949397,  0.39439846, -0.6638417 , -0.25771509],
#        [ 1.27586294, -1.090982  , -0.2685787 , -0.22781692],
#        [-0.50345777,  0.01091857,  1.12520821,  0.19285775],
#        [-0.16174579, -0.25775564,  0.14024168,  1.63260051],
#        [-0.21765365, -0.89400474,  1.02440644,  0.14170198],
#        [ 1.43994003, -1.12821878, -0.31317524,  0.86768961],
#        [-0.15173864,  1.01428269, -0.90348332,  0.72882877],
#        [ 1.26481454,  0.00555041,  1.68152384, -1.13366993],
#        [-0.02159582, -0.86838463, -0.15988647, -0.31789415]])

# %%
df1 = pd.DataFrame(np.random.randn(10,4), index=datas, columns=['São Paulo', 'Santos', 'Corinthias', 'Vasco'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10 entries, 2010-01-01 to 2010-01-10
# Freq: D
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   São Paulo   10 non-null     float64
#  1   Santos      10 non-null     float64
#  2   Corinthias  10 non-null     float64
#  3   Vasco       10 non-null     float64
# dtypes: float64(4)
# memory usage: 400.0 bytes

# %%
df1.shape
# Out:
# (10, 4)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame
