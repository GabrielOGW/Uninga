# %% [markdown]
# # <font color='blue'>Trabalho-Programação Avançada</font>

# %% [markdown]
# Aluno: Gabriel Ogassawara de Souza
#
# Curso: Analise e Desenvolvimento de Sistemas 3º ano Noturno
#
# RA: 93154-21

# %% [markdown]
# A linguagem python é uma das principais para análise de dados. Permite a fácil manipulação de dados,
# sua sintaxe é simples e suas bibliotecas são muito bem aplicáveis a problemas matemáticos.

# %% [markdown]
# 1-Faça as quatro operações matemáticas uma em cada celula com voce escolhendo seus prórios exemplos.

# %% [markdown]
# 2-Façã dois exemplos de potência utilizando um operador matematico e outro com o uso da função python.

# %% [markdown]
# 3-dê três exemplos com a função Type

# %% [markdown]
# 4-Transforme string em inteiro e inteiro em string

# %% [markdown]
# 5-Mostre dois operações com flout e outra inteiro

# %% [markdown]
# 6- Faça um exemplo de cada sobre as Funções abs, round e pow

# %% [markdown]
# 7-Faça exemplos com operadores relacionais: >; <; ==; !=

# %% [markdown]
# 8-Faça 3 exemplos com operadores de distribuição

# %% [markdown]
# 9-Faça dois exemplos com operadores lógicos escolhendo a porta (Booleano)

# %% [markdown]
# 10-Faça uma frase qualquer e busque a indexação de [4]; [1]; [-1];[1:4];[:]

# %% [markdown]
# 11-Faça duas frases com o operador in em seguida use função len para veriticar o tamanho.

# %% [markdown]
# 12- Faça uma frase e use Upper

# %% [markdown]
# 13-Dê um exemplo de declaração multipla

# %% [markdown]
# 14-Faça um exemplo criando variáveis e um calculo final

# %% [markdown]
# 15-Faça um exemplo com Concatenação de Variáveis

# %% [markdown]
# 16-Crie uma lista vazia de coloque 5 elementos nela contendo números e strings

# %% [markdown]
# 17-A partir do exemplo acima, remova o elemento [3]

# %% [markdown]
# 18-A partir o exemplo acima faça um reverse

# %% [markdown]
# 19-Atualize a lista acima colocando um novo elemento da sua preferencia.

# %% [markdown]
# 20-Faça uma lista nova concatendo duas listas

# %% [markdown]
# 21-Dê uma exemplo númerica utilizando as funções masx() e min()

# %% [markdown]
# 22-Crie um dicionário vazio

# %% [markdown]
# 23-A partir do exemplo anterior adcione 5 chaves e 5 valores

# %% [markdown]
# 24-Use o Len para ver o tamanho do dicionário anterior

# %% [markdown]
# 25-faça uma mudança na chave de um dos elementos do exemplo anterior

# %% [markdown]
# 26-Dê um exemplo de interpolação da sua escolha

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 1º Exercicio

# %%
#1 - operações matematicas: soma
a = 5
b = 3
soma = a + b
print(soma)
# Out:
# 8

# %%
#1 - operações matematicas: subtração
a = 7
b = 2
subtracao = a - b
print(subtracao)
# Out:
# 5

# %%
#1 - operações matematicas: multiplicação
a = 4
b = 6
multiplicacao = a * b
print(multiplicacao)
# Out:
# 24

# %%
#1 - operações matematicas: divisão
a = 10
b = 2
divisao = a / b
print(divisao)
# Out:
# 5.0

# %% [markdown]
# ## 2º Exercicio

# %%
#2-potência utilizando um operador matematico
resultado = pow(3, 4)
print(resultado)
# Out:
# 81

# %%
#2- pontecia utilizando a função
resultado = pow(3, 4)
print(resultado)
# Out:
# 81

# %% [markdown]
# ## 3º Exercicio

# %%
#3- exemplos de funçã com a função type: verificando uma string
texto = "Olá, mundo!"
print(type(texto))
# Out:
# <class 'str'>

# %%
#3- exemplos de funçã com a função type: verificando um tipo de lista
lista = [1, 2, 3, 4]
print(type(lista))
# Out:
# <class 'list'>

# %%
#3- exemplos de funçã com a função type: verificando um numero inteiro
numero = 42
print(type(numero))
# Out:
# <class 'int'>

# %% [markdown]
# ## 4º Exercicio

# %%
#4- tranformando um string em numero:
texto = "42"
numero = int(texto)
print(numero)
# Out:
# 42

# %%
#4- tranformando um numero em string:
numero = 42
texto = str(numero)
print(texto)
# Out:
# 42

# %% [markdown]
# ## 5º Exercicio

# %%
#5-operações com float:
resultado1 = 3.5 + 2.25
print(resultado1)

resultado2 = 2.5 * 4.0
print(resultado2)
# Out:
# 5.75
# 10.0

# %%
#5-operações com inteiro e float:
resultado1 = 9 / 2.0
print(resultado1)

resultado2 = 5 + 3.4
print(resultado2)
# Out:
# 4.5
# 8.4

# %% [markdown]
# ## 6º Exercicio

# %%
#6-função abs
numero = -7
abs_numero = abs(numero)
print(abs_numero)
# Out:
# 7

# %%
#6-função round
numero = 6.1234321
numero_arredondado = round(numero, 2)
print(numero_arredondado)
# Out:
# 6.12

# %%
#6-função pow
base = 2
expoente = 3
resultado = pow(base, expoente)
print(resultado)
# Out:
# 8

# %% [markdown]
# ## 7º Exercicio

# %%
#7- exemplo com operador >
a = 5
b = 3
print(a > b)
# Out:
# True

# %%
#7- exemplo com operador <
a = 2
b = 4
print(a < b)
# Out:
# True

# %%
#7- exemplo com operador ==
a = 7
b = 7
print(a == b)
# Out:
# True

# %%
#7- exemplo com operador !=
a = 3
b = 5
print(a != b)
# Out:
# True

# %% [markdown]
# ## 8º Exercicio

# %%
#8- exemplo 1
nome, sobrenome, idade = "Gabriel", "Ogassawara", 21
print(nome)
print(sobrenome)
print(idade)
# Out:
# Gabriel
# Ogassawara
# 21

# %%
#8- exemplo 2
fruta1, fruta2, fruta3 = "maçã", "banana", "laranja"
print(fruta1) 
print(fruta2) 
print(fruta3)
# Out:
# maçã
# banana
# laranja

# %%
#8- exemplo 3
nome1, sobrenome1, idade1 = "João", "Silva", 30
print(nome1, sobrenome1, idade1)
# Out:
# João Silva 30

# %% [markdown]
# ## 9º Exercicio

# %%
#9 - usando operador AND
a = True
b = False
c = a and b
print(c)
# Out:
# False

# %%
#9 - usando operador OR
a = True
b = False
c = a or b
print(c)
# Out:
# True

# %% [markdown]
# ## 10º Exercicio

# %%
frase = "Este é o decimo exercicio do trabalho"
print(frase[4])
print(frase[1])
print(frase[-1])
print(frase[1:4])
print(frase[:])
# Out:
#
# s
# o
# ste
# Este é o decimo exercicio do trabalho

# %% [markdown]
# ## 11º Exercicio

# %%
#11 - frase 1
frase1 = "Dei uma volta no parque"
palavra1 = "parque"
palavra2 = "cachorro"
print(palavra1 in frase1)
print(palavra2 in frase1)
print(len(frase1))
# Out:
# True
# False
# 23

# %%
#11 - frase 2
frase1 = "Dei uma volta com meu cachorro"
palavra1 = "parque"
palavra2 = "cachorro"
print(palavra1 in frase1)
print(palavra2 in frase1)
print(len(frase1))
# Out:
# False
# True
# 30

# %% [markdown]
# ## 12º Exercicio

# %%
frase = "esse trabalho é grande!"
print(frase.upper())
# Out:
# ESSE TRABALHO É GRANDE!

# %% [markdown]
# ## 13º Exercicio

# %%
x = y = z = 0
print(x)
print(y)
print(z)
# Out:
# 0
# 0
# 0

# %% [markdown]
# ## 14º Exercicio

# %%
nota1 = 6
nota2 = 4.3
nota3 = 9.8
media = (nota1 + nota2 + nota3) / 3
print("A média é:", media)
# Out:
# A média é: 6.7

# %% [markdown]
# ## 15º Exercicio

# %%
nome = "Gabriel"
idade = 27
frase = "Oi, meu nome é " + nome + " e eu tenho " + str(idade) + " anos."
print(frase)
# Out:
# Oi, meu nome é Gabriel e eu tenho 27 anos.

# %% [markdown]
# ## 16º Exercicio

# %%
lista = []
lista.append(1)
lista.append("dois")
lista.append(3.5)
lista.append("quatro")
lista.append(5)
print(lista)
# Out:
# [1, 'dois', 3.5, 'quatro', 5]

# %% [markdown]
# ## 17º Exercicio

# %%
del lista[3]
print(lista)
# Out:
# [1, 'dois', 3.5, 5]

# %% [markdown]
# ## 18º Exercicio

# %%
lista.reverse()
print(lista)
# Out:
# ['seis', 1, 'dois', 3.5, 5]

# %% [markdown]
# ## 19º Exercicio

# %%
lista.append("seis")
print(lista)
# Out:
# ['seis', 1, 'dois', 3.5, 5, 'seis', 'seis']

# %% [markdown]
# ## 20º Exercicio

# %%
lista1 = [1, 2, 3]
lista2 = ["quatro", "cinco", "seis"]
lista3 = lista1 + lista2
print(lista3)
# Out:
# [1, 2, 3, 'quatro', 'cinco', 'seis']

# %% [markdown]
# ## 21º Exercicio

# %%
numeros = [10, 5, 20, 8, 15]
maior_valor = max(numeros)
menor_valor = min(numeros)
print("Maior valor:", maior_valor)
print("Menor valor:", menor_valor)
# Out:
# Maior valor: 20
# Menor valor: 5

# %% [markdown]
# ## 22º Exercicio

# %%
meu_dicionario = {}

# %% [markdown]
# ## 23º Exercicio

# %%
meu_dicionario["nome"] = "Gabriel"
meu_dicionario["idade"] = 21
meu_dicionario["cidade"] = "Maringá"
meu_dicionario["curso"] = "Analise e Desenvolvimento de Sistemas"
meu_dicionario["ano_letivo"] = 3
print(meu_dicionario)
# Out:
# {'nome': 'Gabriel', 'idade': 21, 'cidade': 'Maringá', 'curso': 'Analise e Desenvolvimento de Sistemas', 'ano_letivo': 3}

# %% [markdown]
# ## 24º Exercicio

# %%
tamanho = len(meu_dicionario)
print("Tamanho do dicionário:", tamanho)
# Out:
# Tamanho do dicionário: 5

# %% [markdown]
# ## 25º Exercicio

# %%
meu_dicionario["curso"] = "ADS"
print(meu_dicionario)
# Out:
# {'nome': 'Gabriel', 'idade': 21, 'cidade': 'Maringá', 'curso': 'ADS', 'ano_letivo': 3}

# %% [markdown]
# ## 26º Exercicio

# %%
nome = "Gabriel"
idade = 21
mensagem = f"Meu nome é {nome} e tenho {idade} anos."
print(mensagem)
# Out:
# Meu nome é Gabriel e tenho 21 anos.
