# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Estudos/Uninga/datasets_Players.csv')

# %%
df.head()
# Out:
#    Unnamed: 0           Player  height  weight  \
# 0           0  Curly Armstrong   180.0    77.0
# 1           1     Cliff Barker   188.0    83.0
# 2           2    Leo Barnhorst   193.0    86.0
# 3           3       Ed Bartels   196.0    88.0
# 4           4      Ralph Beard   178.0    79.0
#
#                            collage    born   birth_city birth_state
# 0               Indiana University  1918.0          NaN         NaN
# 1           University of Kentucky  1921.0     Yorktown     Indiana
# 2         University of Notre Dame  1924.0          NaN         NaN
# 3  North Carolina State University  1925.0          NaN         NaN
# 4           University of Kentucky  1927.0  Hardinsburg    Kentucky

# %% [markdown]
# # tratando dados:
#
# - qual é a media de altura e peso dos jogadores
# - Criar uma nova coluna entre a razão
# - criar uma nova coluna com IMC dos jogadores
# - qual é a maior altura entre os jogadores
# - qual é a menor altura entre os jogadores
# - qual é o maior peso entre os jogadores
# - qual é o menor peso entre os jogadores
# - qual é o jogador mais alto
# - qual é o jogador mais baixo

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Player', 'height', 'weight', 'collage', 'born',
#        'birth_city', 'birth_state'],
#       dtype='object')

# %%
df.rename(columns={"Player": "Jogador", "height": "Altura", 'weight': 'Peso', 'collage':'Universidade', 'born':'nascimento', 'birth_city':'cidade_nascimento', 'birth_state':'estado_nascimento'})
# Out:
#       Unnamed: 0            Jogador  Altura   Peso  \
# 0              0    Curly Armstrong   180.0   77.0
# 1              1       Cliff Barker   188.0   83.0
# 2              2      Leo Barnhorst   193.0   86.0
# 3              3         Ed Bartels   196.0   88.0
# 4              4        Ralph Beard   178.0   79.0
# ...          ...                ...     ...    ...
# 3917        3917      Troy Williams   198.0   97.0
# 3918        3918       Kyle Wiltjer   208.0  108.0
# 3919        3919  Stephen Zimmerman   213.0  108.0
# 3920        3920        Paul Zipser   203.0   97.0
# 3921        3921        Ivica Zubac   216.0  120.0
#
#                          Universidade  nascimento cidade_nascimento  \
# 0                  Indiana University      1918.0               NaN
# 1              University of Kentucky      1921.0          Yorktown
# 2            University of Notre Dame      1924.0               NaN
# 3     North Carolina State University      1925.0               NaN
# ...

# %%
jogador_mais_alto = df.loc[df['Altura'].idxmax()]
print(jogador_mais_alto)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Altura'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
jogador_mais_baixo = df.loc[df['Altura'].idxmin()]
print(jogador_mais_baixo)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Altura'
#
# The above exception was the direct cause of the following exception:
#
# ...
